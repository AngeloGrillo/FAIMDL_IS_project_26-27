# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eval')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eval

# %%
# !pip install ood-metrics scikit-learn -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 118.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install gitignore_parser==0.1.12 "jsonargparse[signatures]==4.38" timm==1.0.15 lightning==2.5.1.post0 transformers==4.56.1 scipy==1.15.2 fvcore==0.1.5.post20221221 torchmetrics==1.7.1 --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 100.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 142.2 MB/s eta 0:00:00
# ...

# %%
# !python ../evalAnomaly_eomt.py \
    --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/*.png" \
    --config "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml" \
    --ckpt "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin" \
    --method msp \
    --img-size 1024 1024 \
    --num-classes 19
# Out:
# 2026-06-01 16:50:25.745022: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/4.png
# ...

# %%
# !bash ../run_all_eomt.sh 2>&1 | tee ../eomt_results.txt
# Out:
# ...
# CHECKPOINT: EoMT-Cityscapes
# ...
# --- METHOD: msp ---
# Dataset: RoadAnomaly21
# 2026-06-01 16:53:20.360551: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# ...

# %%
with open('../evalAnomaly_eomt.py', 'r') as f:
    content = f.read()

content = content.replace(
    '        # Revert to original image size\n        anomaly_score = anomaly_score.unsqueeze(1).float()\n        anomaly_score = model.revert_window_logits_semantic(\n            anomaly_score.expand(-1, model.num_classes, -1, -1),\n            origins, img_sizes\n        )\n        anomaly_score = anomaly_score[0, 0].cpu().numpy()',
    '        # RbA score è già per-pixel, solo resize all\'originale\n        anomaly_score = anomaly_score[0].float().cpu().numpy()'
)

with open('../evalAnomaly_eomt.py', 'w') as f:
    f.write(content)

print("Fatto!")
# Out:
# Fatto!

# %%
# !bash ../run_all_eomt.sh 2>&1 | tee ../eomt_results.txt
# Out:
# ...
# CHECKPOINT: EoMT-Cityscapes
# ...
# --- METHOD: msp ---
# Dataset: RoadAnomaly21
# 2026-06-01 17:32:25.228180: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# ...

# %%
# !grep -n "rba\|anomaly_score\[0" ../evalAnomaly_eomt.py | head -20
# Out:
# 102:        if method == "rba":
# 134:            anomaly_score = anomaly_score[0, 0].cpu().numpy()
# 171:                        choices=["msp", "maxlogit", "maxentropy", "rba"])

# %%
# !sed -n '125,140p' ../evalAnomaly_eomt.py
# Out:
#             # score = 1 - max confidence over queries
#             anomaly_score = 1.0 - query_confidence.max(dim=1).values  # [B, H, W]
#
#             # Revert to original image size
#             anomaly_score = anomaly_score.unsqueeze(1).float()
#             anomaly_score = model.revert_window_logits_semantic(
#                 anomaly_score.expand(-1, model.num_classes, -1, -1),
#                 origins, img_sizes
#             )
#             anomaly_score = anomaly_score[0, 0].cpu().numpy()
#
#         else:
#             # Get per-pixel logits via semantic inference
#             crop_logits = model.to_per_pixel_logits_semantic(
#                 mask_logits, class_logits_per_layer[-1]
#             )

# %%
# !pip install ood-metrics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 78.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !bash ../run_missing_eomt.sh 2>&1 | tee ../eomt_results_missing.txt
# Out:
# ...
# CHECKPOINT: EoMT-Cityscapes - RbA only
# ...
# Dataset: RoadAnomaly21
# 2026-06-02 17:17:55.515967: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# ...

# %%
import torch
state_dict = torch.load("/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_coco.bin", map_location="cpu", weights_only=True)
print(state_dict['network.class_head.weight'].shape)
# Out:
# torch.Size([134, 768])

# %%
import torch
import sys
sys.path.insert(0, '/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt')

# Verifica quante classi ha il modello quando lo carichiamo con num_classes=133
state_dict = torch.load("/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_coco.bin", map_location="cpu", weights_only=True)
for k,v in state_dict.items():
    if 'class_head' in k or 'empty_weight' in k:
        print(k, v.shape)
# Out:
# network.class_head.weight torch.Size([134, 768])
# network.class_head.bias torch.Size([134])
# criterion.empty_weight torch.Size([134])

# %%
with open('../run_missing_eomt.sh', 'r') as f:
    content = f.read()

content = content.replace('--num-classes 134', '--num-classes 133')

with open('../run_missing_eomt.sh', 'w') as f:
    f.write(content)

print("Fatto!")
# Out:
# Fatto!

# %%
# !python ../evalAnomaly_eomt.py \
    --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/*.png" \
    --config "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml" \
    --ckpt "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_coco.bin" \
    --method msp \
    --img-size 640 640 \
    --num-classes 133 \
    --num-q 200
# Out:
# 2026-06-02 17:41:08.252495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_coco.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/4.png
# ...

# %%
# !bash ../run_missing_eomt.sh 2>&1 | tee ../eomt_results_missing.txt
# Out:
# ...
# CHECKPOINT: EoMT-Cityscapes - RbA only
# ...
# Dataset: RoadAnomaly21
# 2026-06-02 17:42:09.484692: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/9.png
# ...

# %% [markdown]
# TEMPERATURE SCALING

# %%
# !cat ../eval/evalAnomaly_all.py | grep -A 30 "temperature"

# %%
# !sed -n '100,145p' ../evalAnomaly_eomt.py
# Out:
#         )
#
#         if method == "rba":
#             # RbA: Rejected by All
#             # For each pixel, compute the probability that NO query claims it
#             # score = product over queries of (1 - sigmoid(mask_logit_i) * p_i(c_i))
#             # High score = no query claims the pixel = anomaly
#             class_logits = class_logits_per_layer[-1]  # [B, Q, C+1]
#
#             # Get per-query class probabilities (excluding no-object class)
#             # softmax over classes excluding last (no-object)
#             class_probs = F.softmax(class_logits[..., :-1], dim=-1)  # [B, Q, C]
#             max_class_probs = class_probs.max(dim=-1).values  # [B, Q]
#
#             # Mask sigmoid
#             mask_probs = mask_logits.sigmoid()  # [B, Q, H, W]
#
#             # RbA score: for each pixel, min over queries of (1 - mask * class_prob)
#             # Reshape max_class_probs for broadcasting: [B, Q, 1, 1]
# ...

# %%
# !grep -n "^def " ../evalAnomaly_eomt.py
# Out:
# 45:def load_eomt_model(config_path, ckpt_path, img_size, num_classes,
# 83:def get_anomaly_score(model, image_tensor, method, device):
# 160:def main():

# %%
# !sed -n '1,44p' ../evalAnomaly_eomt.py
# Out:
# """
# Point 8 - EoMT Anomaly Segmentation Evaluation
# Supports: MSP, MaxLogit, MaxEntropy, RbA
# Works with all 3 EoMT checkpoints: COCO, Cityscapes, Finetuned
# """
#
# import sys
# sys.path.insert(0, '/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt')
#
# import os
# import glob
# import torch
# import random
# import warnings
# import importlib
# import numpy as np
# import yaml
# from PIL import Image
# from argparse import ArgumentParser
# from torch.nn import functional as F
# from torch.amp.autocast_mode import autocast
# from torchvision.transforms import Compose, Resize, ToTensor
# from sklearn.metrics import average_precision_score
# from ood_metrics import fpr_at_95_tpr
#
# warnings.filterwarnings("ignore", message=r".*Attribute 'network'.*")
#
# seed = 42
# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = True
# ...

# %%
# !python ../save_logits_eomt.py \
    --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/*.png" \
    --config "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml" \
    --ckpt "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin" \
    --output-dir "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/logits_cache/cityscapes/RoadAnomaly21" \
    --img-size 1024 1024 \
    --num-classes 19
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 124MB/s]
# 2026-06-02 22:20:08.805528: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/0.png
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eval/../save_logits_eomt.py", line 45, in <module>
#     main()
# ...

# %%
# !sed -n '83,135p' ../evalAnomaly_eomt.py
# Out:
# def get_anomaly_score(model, image_tensor, method, device):
#     """
#     Compute anomaly score for a single image using EoMT semantic inference.
#
#     For MSP, MaxLogit, MaxEntropy: use per-pixel logits from semantic inference
#     For RbA: use mask logits and class logits directly (mask architecture specific)
#     """
#     imgs = [image_tensor.to(device)]
#     img_sizes = [image_tensor.shape[-2:]]
#
#     with autocast(dtype=torch.float16, device_type="cuda"):
#         crops, origins = model.window_imgs_semantic(imgs)
#         mask_logits_per_layer, class_logits_per_layer = model(crops)
#
#         # Interpolate mask logits to model img_size
#         mask_logits = F.interpolate(
#             mask_logits_per_layer[-1], model.img_size, mode="bilinear"
#         )
#
#         if method == "rba":
#             # RbA: Rejected by All
#             # For each pixel, compute the probability that NO query claims it
# ...

# %%
# !python ../save_logits_eomt.py \
    --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/*.png" \
    --config "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml" \
    --ckpt "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin" \
    --output-dir "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/logits_cache/cityscapes/RoadAnomaly21" \
    --img-size 1024 1024 \
    --num-classes 19
# Out:
# 2026-06-02 22:22:02.382495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/0.png
#   saved 0.npy, shape=(19, 512, 1024)
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/1.png
#   saved 1.npy, shape=(19, 512, 1024)
# ...

# %%
# !bash ../run_save_logits.sh 2>&1 | tee ../save_logits_log.txt
# Out:
# Cityscapes - RoadAnomaly21
# 2026-06-02 22:24:11.767477: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded from /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/trained_models/eomt_cityscapes.bin
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/0.png
#   saved 0.npy, shape=(19, 512, 1024)
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/RoadAnomaly21/images/1.png
#   saved 1.npy, shape=(19, 512, 1024)
# ...

# %%
# !python ../temp_scaling_eomt.py 2>&1 | tee ../temp_scaling_results.txt
# Out:
# ...
# CHECKPOINT: EoMT-cityscapes
# ...
# Dataset: RoadAnomaly21
#   T=0.50  AUPRC=69.45%  FPR95=14.10%
#   T=0.75  AUPRC=69.54%  FPR95=14.10%
#   T=1.00  AUPRC=69.60%  FPR95=14.10%
#   T=1.10  AUPRC=69.62%  FPR95=14.10%
#   T=1.50  AUPRC=69.71%  FPR95=14.10%
#   T=2.00  AUPRC=69.77%  FPR95=14.10%
# Dataset: RoadObsticle21
#   T=0.50  AUPRC=84.29%  FPR95=4.42%
#   T=0.75  AUPRC=84.27%  FPR95=4.48%
#   T=1.00  AUPRC=84.27%  FPR95=4.49%
#   T=1.10  AUPRC=84.27%  FPR95=4.50%
#   T=1.50  AUPRC=84.26%  FPR95=4.51%
#   T=2.00  AUPRC=84.26%  FPR95=4.53%
# Dataset: FS_LostFound_full
# Traceback (most recent call last):
# tee: ../temp_scaling_results.txt: Transport endpoint is not connected
#   File "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/eval/../temp_scaling_eomt.py", line 55, in <module>
# ...

# %%
import glob
img_paths = sorted(glob.glob("/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/FS_LostFound_full/images/*.png"))
print(img_paths[0])
print(img_paths[0].replace("images", "labels_masks"))
# Out:
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/FS_LostFound_full/images/0.png
# /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject-main/MaskArchitectureAnomaly_CourseProject-main/Validation_Dataset/FS_LostFound_full/labels_masks/0.png

# %%
# !python ../temp_scaling_eomt.py 2>&1 | tee ../temp_scaling_results.txt
# Out:
# ...
# CHECKPOINT: EoMT-cityscapes
# ...
# Dataset: RoadAnomaly21
#   T=0.50  AUPRC=69.45%  FPR95=14.10%
#   T=0.75  AUPRC=69.54%  FPR95=14.10%
#   T=1.00  AUPRC=69.60%  FPR95=14.10%
#   T=1.10  AUPRC=69.62%  FPR95=14.10%
#   T=1.50  AUPRC=69.71%  FPR95=14.10%
#   T=2.00  AUPRC=69.77%  FPR95=14.10%
# Dataset: RoadObsticle21
#   T=0.50  AUPRC=84.29%  FPR95=4.42%
#   T=0.75  AUPRC=84.27%  FPR95=4.48%
#   T=1.00  AUPRC=84.27%  FPR95=4.49%
#   T=1.10  AUPRC=84.27%  FPR95=4.50%
#   T=1.50  AUPRC=84.26%  FPR95=4.51%
#   T=2.00  AUPRC=84.26%  FPR95=4.53%
# Dataset: FS_LostFound_full
#   T=0.50  AUPRC=16.80%  FPR95=10.19%
#   T=0.75  AUPRC=16.81%  FPR95=10.18%
#   T=1.00  AUPRC=16.81%  FPR95=10.17%
#   T=1.10  AUPRC=16.81%  FPR95=10.17%
#   T=1.50  AUPRC=16.82%  FPR95=10.16%
#   T=2.00  AUPRC=16.83%  FPR95=10.16%
# Dataset: fs_static
#   T=0.50  AUPRC=31.58%  FPR95=38.39%
#   T=0.75  AUPRC=31.59%  FPR95=38.38%
#   T=1.00  AUPRC=31.60%  FPR95=38.39%
#   T=1.10  AUPRC=31.60%  FPR95=38.39%
# ...
